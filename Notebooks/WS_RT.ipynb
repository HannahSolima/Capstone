# %%
import requests
from bs4 import BeautifulSoup as BS
from IPython.core.display import HTML
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:105.0) Gecko/20100101 Firefox/105.0'
}

# %%
titles = ['The Shawshank Redemption', 'The Godfather','The Dark Knight','The Godfather Part II','12 Angry Men',"Schindler's List",'The Lord of the Rings: The Return of the King','Pulp Fiction','The Lord of the Rings: The Fellowship of the Ring','The Good, the Bad and the Ugly','Forrest Gump','Fight Club','The Lord of the Rings: The Two Towers','Inception','Star Wars: Episode V - The Empire Strikes Back','The Matrix','Goodfellas',"One Flew Over the Cuckoo's Nest",'Se7en','Seven Samurai',"It's a Wonderful Life",'The Silence of the Lambs','City of God','Saving Private Ryan','Life Is Beautiful','Interstellar','The Green Mile','Star Wars','Terminator 2: Judgment Day','Back to the Future','Spirited Away','Psycho','The Pianist','Parasite','Léon: The Professional','The Lion King','Gladiator','American History X','The Departed','The Usual Suspects','The Prestige','Whiplash','Casablanca','Harakiri','The Intouchables','Grave of the Fireflies','Modern Times','Once Upon a Time in the West','Rear Window','Cinema Paradiso','Alien','City Lights','Apocalypse Now','Memento','Raiders of the Lost Ark','Django Unchained','WALL·E','The Lives of Others','Sunset Blvd.','Paths of Glory','The Great Dictator','The Shining','Avengers: Infinity War','Witness for the Prosecution','Aliens','Spider-Man: Into the Spider-Verse','American Beauty','Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb','The Dark Knight Rises','Oldboy','Amadeus','Joker','Inglourious Basterds','Coco','Toy Story','Braveheart','The Boat','Avengers: Endgame','Princess Mononoke','Once Upon a Time in America','Good Will Hunting','Top Gun: Maverick','Your Name.','Requiem for a Dream','3 Idiots',"Singin' in the Rain",'Toy Story 3','High and Low','Star Wars: Episode VI - Return of the Jedi','Capernaum','2001: A Space Odyssey','Eternal Sunshine of the Spotless Mind','Reservoir Dogs','The Hunt','Come and See','Citizen Kane','M','Lawrence of Arabia','North by Northwest','Vertigo','Amélie','A Clockwork Orange','The Apartment','Ikiru','Double Indemnity','Full Metal Jacket','Hamilton','Scarface','The Sting','To Kill a Mockingbird','Incendies','Up','Heat','Taxi Driver','A Separation','Metropolis','L.A. Confidential','Snatch','Die Hard','Bicycle Thieves','Indiana Jones and the Last Crusade','Like Stars on Earth','1917','Downfall','For a Few Dollars More','Dangal','Batman Begins','The Kid','Some Like It Hot','The Father','All About Eve','Green Book','The Wolf of Wall Street','Judgment at Nuremberg','Ran','Casino',"Pan's Labyrinth",'Unforgiven','There Will Be Blood','The Truman Show','The Sixth Sense','A Beautiful Mind','Spider-Man: No Way Home','Yojimbo','Shutter Island','Monty Python and the Holy Grail','The Treasure of the Sierra Madre','Jurassic Park','The Great Escape','Rashomon','Kill Bill: Vol. 1','No Country for Old Men','Finding Nemo','The Thing','The Elephant Man','Chinatown','Raging Bull','Gone with the Wind','V for Vendetta','Inside Out','Lock, Stock and Two Smoking Barrels','Dial M for Murder','The Secret in Their Eyes',"Howl's Moving Castle",'The Bridge on the River Kwai','Three Billboards Outside Ebbing, Missouri','Trainspotting','Warrior','Fargo','Gran Torino','Prisoners','My Neighbor Totoro','Catch Me If You Can','Million Dollar Baby','Children of Heaven','The Gold Rush','Blade Runner','On the Waterfront','Before Sunrise','12 Years a Slave','Harry Potter and the Deathly Hallows: Part 2','Ben-Hur','Wild Strawberries','Gone Girl','The Third Man','The General','The Grand Budapest Hotel','The Deer Hunter','In the Name of the Father','The Wages of Fear','Barry Lyndon','Klaus','Hacksaw Ridge','Mr. Smith Goes to Washington','Sherlock Jr.','Memories of Murder','Wild Tales','The Seventh Seal','Room','Mad Max: Fury Road','Mary and Max','How to Train Your Dragon','The Big Lebowski','Monsters, Inc.','Jaws','Dead Poets Society','The Passion of Joan of Arc','Tokyo Story','Hotel Rwanda','Ford v Ferrari','Rocky','Platoon','Stand by Me','Spotlight','The Terminator','Logan','Ratatouille','Rush','Pather Panchali','Network','Into the Wild','The Wizard of Oz','Before Sunset','Groundhog Day','The Exorcist','The Best Years of Our Lives','The Incredibles','To Be or Not to Be','The Battle of Algiers','Jai Bhim',"Hachi: A Dog's Tale",'La haine','My Father and My Son','Pirates of the Caribbean: The Curse of the Black Pearl','The Grapes of Wrath','Amores perros','Rebecca','Cool Hand Luke','Everything Everywhere All at Once','The 400 Blows','The Handmaiden','It Happened One Night','Persona','The Sound of Music','Life of Brian','Dersu Uzala','Aladdin','The Help','The Iron Giant','Gandhi']

# %%
titles
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Dark Knight',
#  'The Godfather Part II',
#  '12 Angry Men',
#  "Schindler's List",
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Good, the Bad and the Ugly',
#  'Forrest Gump',
#  'Fight Club',
#  'The Lord of the Rings: The Two Towers',
#  'Inception',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'The Matrix',
#  'Goodfellas',
#  "One Flew Over the Cuckoo's Nest",
#  'Se7en',
#  'Seven Samurai',
#  "It's a Wonderful Life",
#  'The Silence of the Lambs',
#  'City of God',
#  'Saving Private Ryan',
#  'Life Is Beautiful',
#  'Interstellar',
#  'The Green Mile',
#  'Star Wars',
#  'Terminator 2: Judgment Day',
#  'Back to the Future',
#  'Spirited Away',
#  'Psycho',
#  'The Pianist',
#  'Parasite',
#  'Léon: The Professional',
#  'The Lion King',
#  'Gladiator',
#  'American History X',
#  'The Departed',
# ...

# %% [markdown]
# #### Edit Titles to have "_" instead of spaces and "/m/" in the beginning

# %%
titles_clean1 = [x.replace(' ', '_').replace("'",'').replace(':','').replace('-','').replace('·','_') for x in titles]
titles_clean2 = [x.replace('.','').replace('é','e').replace(',','') for x in titles_clean1]

# %%
#special titles
titles_clean3  = [x.replace('Dr_Strangelove_or_How_I_Learned_to_Stop_Worrying_and_Love_the_Bomb','Dr_Strangelove') for x in titles_clean2]
titles_clean4 = [x.replace('12_Angry_Men','1000013_12_Angry_men') for x in titles_clean3]
titles_clean = [x.replace('Whiplash','whiplash_2014') for x in titles_clean4]

# %%
titles_clean
# Out:
# ['The_Shawshank_Redemption',
#  'The_Godfather',
#  'The_Dark_Knight',
#  'The_Godfather_Part_II',
#  '1000013_12_Angry_men',
#  'Schindlers_List',
#  'The_Lord_of_the_Rings_The_Return_of_the_King',
#  'Pulp_Fiction',
#  'The_Lord_of_the_Rings_The_Fellowship_of_the_Ring',
#  'The_Good_the_Bad_and_the_Ugly',
#  'Forrest_Gump',
#  'Fight_Club',
#  'The_Lord_of_the_Rings_The_Two_Towers',
#  'Inception',
#  'Star_Wars_Episode_V__The_Empire_Strikes_Back',
#  'The_Matrix',
#  'Goodfellas',
#  'One_Flew_Over_the_Cuckoos_Nest',
#  'Se7en',
#  'Seven_Samurai',
#  'Its_a_Wonderful_Life',
#  'The_Silence_of_the_Lambs',
#  'City_of_God',
#  'Saving_Private_Ryan',
#  'Life_Is_Beautiful',
#  'Interstellar',
#  'The_Green_Mile',
#  'Star_Wars',
#  'Terminator_2_Judgment_Day',
#  'Back_to_the_Future',
#  'Spirited_Away',
#  'Psycho',
#  'The_Pianist',
#  'Parasite',
#  'Leon_The_Professional',
#  'The_Lion_King',
#  'Gladiator',
#  'American_History_X',
#  'The_Departed',
#  'The_Usual_Suspects',
# ...

# %%
#71,76,63,87,96,98, 24, 32, 41, 43, 45, 51,59,103, 
#33

# %% [markdown]
# #### Retrieving Original Language

# %%
#parent = tester2.find('ul', attrs={'class': 'content-meta info'})

# %%
#children = parent.findChildren("li" , recursive=False)

# %%
#children

# %%
#children.tolist

# %%
# if children.isin('*Rating*'):
#     print('yay')
# else:
#     print('boo')

# %%
# org_lang = []
# for x in titles_clean[0:15]:
#     try: 
#         IMDb_soup = BS(requests.get(f'https://www.rottentomatoes.com/m/{x}', headers = headers).text)
#         if IMDb_soup.find('div', attrs = {'class' : 'meta-label subtle'}).text == 'Original Language':
#             org_lang.append(IMDb_soup.findAll('div', attrs = {'class' : 'meta-value'})[2].text.strip(' ').strip('\n'))
#         else:
#             org_lang.append('did not work :(')
#     except:
#         org_lang.append("Not Available on IMDb")

# %%
# org_lang

# %%
# for ______:
#     try:
#         value = imdb_soup.findAll('dif', attrs = {'class' : 'meta-value'})[2].text.strip(' ').strip('\n')
#         if value =
        
# <div class="meta-label subtle" data-qa="movie-info-item-label">Original Language:</div>    
    
#     IMDb_soup = BS(requests.get(f'https://www.rottentomatoes.com/m/{x}', headers = headers).text)
#             org_lang.append(IMDb_soup.findAll('div', attrs = {'class':'meta-value'})[2].text.strip(' ').strip('\n'))

# %%
# if imdb_soup.findAll('dif', attrs = {'class' : 'meta-label subtle'}) == 'Original Language':
#      org_lang.append(imdb_soup.findAll('dif', attrs = {'class' : 'meta-value'})[2].text..strip(' ').strip('\n'))

# %%
tester2 = BS(requests.get(f'https://www.rottentomatoes.com/m/The_Shawshank_Redemption', headers = headers).text)
tester2
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
# <!-- OneTrust Cookies Consent Notice start for rottentomatoes.com -->
# <script charset="UTF-8" crossorigin="anonymous" data-domain-script="7e979733-6841-4fce-9182-515fac69187f" integrity="sha384-WEHwEli88wqOiQd913F1utFZiwisa8XhCkbjLnbKEpFa/WbFcPKeGg7h4fdsv0Z/" src="https://cdn.cookielaw.org/consent/7e979733-6841-4fce-9182-515fac69187f/otSDKStub.js" type="text/javascript">
# </script>
# <script type="text/javascript">
#             function OptanonWrapper() { }
#             </script>
# <!-- OneTrust Cookies Consent Notice end for rottentomatoes.com -->
# <!-- OneTrust IAB US Privacy (USP) -->
# ...

# %%
# org_lang

# %%
# len(org_lang)

# %% [markdown]
# #### US Box Office (gross amount)

# %%
box = []
for x in titles_clean:
    try: 
        IMDb_soup = BS(requests.get(f'https://www.rottentomatoes.com/m/{x}', headers = headers).text)
        box.append(IMDb_soup.findAll('div', attrs = {'class':'meta-value'})[8].text)
    except:
        box.append("Not Available on IMDb")

# %%
box
# Out:
# ['$27.3M',
#  '$134.8M',
#  '$2.0M',
#  'Not Available on IMDb',
#  '\n                        \n                        Criterion Collection, \n                        \n                        MGM/UA Home Entertainment Inc., \n                        \n                        United Artists, \n                        \n                        Metro-Goldwyn-Mayer\n                        \n                    ',
#  '$96.6M',
#  '$377.8M',
#  '\n\n                            2h 33m\n                        \n',
#  '$315.5M',
#  '\n\n                            2h 41m\n                        \n',
#  '$330.3M',
#  '$37.0M',
#  '$342.6M',
#  '$292.6M',
#  'Not Available on IMDb',
#  '$171.4M',
#  '$42.6M',
#  '\n\n                            2h 13m\n                        \n',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '$3.3M',
#  '$130.7M',
#  '$7.6M',
#  '\n\n                            2h 49m\n                        \n',
#  'Not Available on IMDb',
#  '$188.0M',
# ...

# %%
len(box)
# Out:
# 250

# %% [markdown]
# #### Distributor

# %%
dist = []
for x in titles_clean:
    try: 
        IMDb_soup = BS(requests.get(f'https://www.rottentomatoes.com/m/{x}', headers = headers).text)
        dist.append(IMDb_soup.findAll('div', attrs = {'class':'meta-value'})[10].text.replace('\n','').replace(' ',''))
    except:
        dist.append("Not Available on IMDb")

# %%
dist
# Out:
# ['ColumbiaPictures',
#  'ParamountPictures',
#  'WarnerBros.',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  'UniversalPictures',
#  'NewLineCinema',
#  'DolbyDigital,DolbySR,Stereo,DolbyStereo,DolbyA',
#  'WarnerBros.,NewLineCinema,ArgentinaVideoHome,FSFilmOy',
#  'Not Available on IMDb',
#  'ParamountPictures',
#  '20thCenturyFox',
#  'NewLineCinema',
#  'WarnerBros.Pictures',
#  'Not Available on IMDb',
#  'WarnerBros.Pictures',
#  'WarnerBros.Pictures',
#  'Mono',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  'RKORadioPictures',
#  'OrionPictures',
#  'MiramaxFilms',
#  'DolbySR,DTS,DolbyStereo,Surround,SDDS,DolbyA,DolbyDigital',
#  'Not Available on IMDb',
#  'ParamountPictures',
#  'WarnerBros.Pictures,WarnerHomeVídeo,WarnerBros.',
#  'Surround',
#  'TriStarPictures,PioneerEntertainment,ArtisanEntertainment,LiveVideo',
#  'UniversalPictures',
#  'WaltDisneyPictures',
#  'Mono',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
# ...

# %%
len(dist)
# Out:
# 250

# %% [markdown]
# #### Count of Audience Reviews

# %%
aud_rev = []
for x in titles_clean:
    try: 
        IMDb_soup = BS(requests.get(f'https://www.rottentomatoes.com/m/{x}', headers = headers).text)
        aud_rev.append(IMDb_soup.findAll('a', attrs = {'slot':'audience-count'})[0].text.strip(' Ratings'))
    except:
        aud_rev.append("Not Available on IMDb")

# %%
aud_rev
# Out:
# ['250,000+',
#  '250,000+',
#  '250,000+',
#  'Not Available on IMDb',
#  '100,000+',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  '100,000+',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  'Not Available on IMDb',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '100,000+',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  '0',
#  '100,000+',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  '100,000+',
#  '100+',
#  'Fewer than 50',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '50,000+',
#  'Not Available on IMDb',
#  '5,000+',
#  '25,000+',
#  '50,000+',
#  '25,000+',
#  '50,000+',
#  '100,000+',
#  '50,000+',
#  '250,000+',
#  '25,000+',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  '250,000+',
#  '100,000+',
#  'Not Available on IMDb',
#  '25,000+',
# ...

# %%
len(aud_rev)
# Out:
# 250

# %% [markdown]
# #### Count of Critics Reviews

# %%
crit_rev = []
for x in titles_clean:
    try: 
        IMDb_soup = BS(requests.get(f'https://www.rottentomatoes.com/m/{x}', headers = headers).text)
        crit_rev.append(IMDb_soup.findAll('a', attrs = {'slot':'critics-count'})[0].text.strip(' Reviews'))
    except:
        crit_rev.append("Not Available on IMDb")

# %%
crit_rev
# Out:
# ['82',
#  '149',
#  '345',
#  'Not Available on IMDb',
#  '58',
#  '130',
#  '274',
#  '113',
#  '234',
#  '75',
#  '106',
#  '181',
#  '256',
#  '364',
#  'Not Available on IMDb',
#  '161',
#  '107',
#  '116',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '92',
#  '148',
#  '164',
#  '146',
#  '0',
#  '372',
#  '136',
#  '137',
#  '83',
#  '86',
#  '195',
#  '109',
#  '0',
#  '3',
#  '65',
#  '135',
#  '252',
#  '86',
#  '284',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '303',
#  'Not Available on IMDb',
#  '10',
#  '130',
#  '42',
#  '111',
#  '66',
#  '126',
#  '82',
#  '132',
#  '59',
#  '98',
#  '179',
#  '91',
#  '297',
#  '261',
#  '163',
#  'Not Available on IMDb',
#  '74',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '489',
#  '36',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '191',
#  '96',
#  '375',
#  '151',
#  '153',
#  '0',
#  '332',
#  '0',
#  '96',
#  'Not Available on IMDb',
#  '2',
#  '554',
#  '0',
#  '55',
# ...

# %%
len(crit_rev)
# Out:
# 250

# %% [markdown]
# #### Audience Score

# %%
aud_score = []
for x in titles_clean:
    try: 
        IMDb_soup = BS(requests.get(f'https://www.rottentomatoes.com/m/{x}', headers = headers).text)
        aud_score.append(IMDb_soup.findAll('score-board')[0].get('audiencescore'))
    except:
        aud_score.append("Not Available on IMDb")

# %%
aud_score
# Out:
# ['98',
#  '98',
#  '94',
#  'Not Available on IMDb',
#  '97',
#  '97',
#  '86',
#  '96',
#  '95',
#  '97',
#  '95',
#  '96',
#  '95',
#  '91',
#  'Not Available on IMDb',
#  '85',
#  '97',
#  '96',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '95',
#  '95',
#  '97',
#  '95',
#  '',
#  '86',
#  '94',
#  '96',
#  '95',
#  '94',
#  '96',
#  '95',
#  '33',
#  '',
#  '95',
#  '93',
#  '87',
#  '96',
#  '94',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '94',
#  'Not Available on IMDb',
#  '97',
#  '93',
#  '95',
#  '95',
#  '95',
#  '95',
#  '97',
#  '94',
#  '96',
#  '94',
#  '94',
#  '96',
#  '92',
#  '90',
#  '96',
#  'Not Available on IMDb',
#  '95',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '91',
#  '95',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '93',
#  '94',
#  '90',
#  '94',
#  '95',
#  '33',
#  '88',
#  '15',
#  '92',
#  'Not Available on IMDb',
#  '82',
#  '90',
#  '',
#  '93',
#  '94',
#  '99',
#  '96',
#  '93',
# ...

# %%
len(aud_score)
# Out:
# 250

# %% [markdown]
# #### Tomatometer Score

# %%
tom_score = []
for x in titles_clean:
    try: 
        IMDb_soup = BS(requests.get(f'https://www.rottentomatoes.com/m/{x}', headers = headers).text)
        tom_score.append(IMDb_soup.findAll('score-board')[0].get('tomatometerscore'))
    except:
        tom_score.append("Not Available on IMDb")

# %%
tom_score
# Out:
# ['91',
#  '97',
#  '94',
#  'Not Available on IMDb',
#  '100',
#  '98',
#  '93',
#  '92',
#  '91',
#  '97',
#  '71',
#  '79',
#  '95',
#  '87',
#  'Not Available on IMDb',
#  '88',
#  '96',
#  '93',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '93',
#  '95',
#  '91',
#  '94',
#  '',
#  '73',
#  '79',
#  '93',
#  '93',
#  '97',
#  '97',
#  '96',
#  '',
#  '',
#  '74',
#  '93',
#  '79',
#  '83',
#  '90',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '94',
#  'Not Available on IMDb',
#  '100',
#  '76',
#  '100',
#  '98',
#  '95',
#  '98',
#  '90',
#  '98',
#  '97',
#  '98',
#  '93',
#  '96',
#  '87',
#  '95',
#  '92',
#  'Not Available on IMDb',
#  '96',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '85',
#  '100',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '87',
#  '98',
#  '87',
#  '82',
#  '89',
#  '',
#  '89',
#  '',
#  '100',
#  'Not Available on IMDb',
#  '',
#  '94',
#  '',
#  '87',
#  '97',
#  '96',
#  '',
#  '78',
# ...

# %% [markdown]
# #### Rotten Tomatoes Star Score

# %%
rt_star = []
for x in titles_clean:
    try: 
        IMDb_soup = BS(requests.get(f'https://www.rottentomatoes.com/m/{x}', headers = headers).text)
        rt_star.append(IMDb_soup.findAll('score-board')[0].get('tomatometerscore'))
    except:
        rt_star.append("Not Available on IMDb")

# %%
rt_star
# Out:
# ['91',
#  '97',
#  '94',
#  'Not Available on IMDb',
#  '100',
#  '98',
#  '93',
#  '92',
#  '91',
#  '97',
#  '71',
#  '79',
#  '95',
#  '87',
#  'Not Available on IMDb',
#  '88',
#  '96',
#  '93',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '93',
#  '95',
#  '91',
#  '94',
#  '',
#  '73',
#  '79',
#  '93',
#  '93',
#  '97',
#  '97',
#  '96',
#  '',
#  '',
#  '74',
#  '93',
#  '79',
#  '83',
#  '90',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '94',
#  'Not Available on IMDb',
#  '100',
#  '76',
#  '100',
#  '98',
#  '95',
#  '98',
#  '90',
#  '98',
#  '97',
#  '98',
#  '93',
#  '96',
#  '87',
#  '95',
#  '92',
#  'Not Available on IMDb',
#  '96',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  '85',
#  '100',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
#  'Not Available on IMDb',
# ...

# %%
len(rt_star)
# Out:
# 250

# %% [markdown]
# #### DataFrame

# %%
# table = {'Title_ID':title_id,'Tomatometer':tom_score,'RT_Star_Score': TBD,'Critic_Reviews':crit_rev,'Audience_Score':aud_score, 'Audience_Reviews': aud_rev, 'US_Box_Office': box, 'Distibutor':dist,'Original_Language':org_lang}

# Rotten_Tomatoes = pd.DataFrame(table, columns=['Title_ID','Tomatometer','RT_Star_Score', 'Audience_Score', 'Critic_Reviews', 'Audience_Reviews', 'US_Box_Office', 'Distributor', 'Original_Language'])

# Rotten_Tomatoes

# %% [markdown]
# #### Save CSV

# %%
#TBD

# %% [markdown]
# #### TESTER CODES

# %%
test = BS(requests.get(f'https://www.rottentomatoes.com/m/The_Shawshank_Redemption', headers = headers).text)
test.findAll('div')
# Out:
# [<div id="auth-templates">
#  <template id="cognito-loading" slot="screens">
#  <div>
#  <loading-spinner id="cognito-auth-loading-spinner"></loading-spinner>
#  <style>
#              #cognito-auth-loading-spinner {
#                  font-size: 2em;
#                  transform: translate(calc(100% - 1em), 250px);
#                  width: 50%;
#              }
#          </style>
#  </div>
#  </template>
#  <template id="cognito-signup-form" slot="screens">
#  <auth-signup-screen data-qa="auth-signup-screen">
#  <h2 class="cognito-signup-form__header" data-qa="auth-signup-screen-title" slot="header">Log in or sign up for Rotten Tomatoes</h2>
#  <rt-button class="cognito-signup-form__option" data-qa="auth-signup-screen-google-btn" slot="signup-option" theme="light" value="google">
#  <div class="cognito-signup-form__option__container">
#  <span class="cognito-signup-form__option__icon cognito-signup-form__option__icon--google"></span>
# ...

# %%
#original language
test1 = BS(requests.get(f'https://www.rottentomatoes.com/m/The_Shawshank_Redemption', headers = headers).text)
test1.findAll('div', attrs = {'class':'meta-value'})[2].text.strip(' ').strip('\n')
# Out:
# 'English'

# %%
#US Box Office
test2 = BS(requests.get(f'https://www.rottentomatoes.com/m/The_Shawshank_Redemption', headers = headers).text)
test2.findAll('div', attrs = {'class':'meta-value'})[8].text
# Out:
# '$27.3M'

# %%
#distributor
test3 = BS(requests.get(f'https://www.rottentomatoes.com/m/The_Shawshank_Redemption', headers = headers).text)
test3.findAll('div', attrs = {'class':'meta-value'})[10].text.replace('\n','').strip(' ')
# Out:
# 'Columbia Pictures'

# %%
#audience count
test4 = BS(requests.get(f'https://www.rottentomatoes.com/m/The_Shawshank_Redemption', headers = headers).text)
test4.findAll('a', attrs = {'slot':'audience-count'})[0].text.strip(' Ratings')
# Out:
# '250,000+'

# %%
#critics count
test5 =BS(requests.get(f'https://www.rottentomatoes.com/m/The_Shawshank_Redemption', headers = headers).text)
test5.findAll('a', attrs = {'slot':'critics-count'})[0].text.strip(' Reviews')
# Out:
# '82'

# %%
#audience score
test6 = BS(requests.get(f'https://www.rottentomatoes.com/m/The_Shawshank_Redemption', headers = headers).text)
test6.findAll('score-board')[0].get('audiencescore')
# Out:
# '98'

# %%
#tomatometer
test7 = BS(requests.get(f'https://www.rottentomatoes.com/m/The_Shawshank_Redemption', headers = headers).text)
test7.findAll('score-board')[0].get('tomatometerscore')
# Out:
# '91'

# %% [markdown]
# #### Work in progress

# %%
#RT Star
test8 = BS(requests.get(f'https://www.rottentomatoes.com/m/The_Shawshank_Redemption', headers = headers).text)
test8.findAll('div')[25]#.find('star-rating').get('averagestars')
# Out:
# <div class="trending-list-wrap" data-qa="trending-bar" id="trending-bar-start">
# <ul class="list-inline trending-bar__list" data-curation="rt-nav-trending" data-qa="trending-bar-list">
# <li class="trending-bar__header">Trending on RT</li>
# <li><a class="trending-bar__link" data-qa="trending-bar-item" href="https://www.rottentomatoes.com/daily/"> Daily Tomato </a></li>
# <li><a class="trending-bar__link" data-qa="trending-bar-item" href="https://www.rottentomatoes.com/m/guillermo_del_toros_pinocchio"> Guillermo del Toro's Pinocchio  </a></li>
# <li><a class="trending-bar__link" data-qa="trending-bar-item" href="https://www.rottentomatoes.com/m/troll_2022"> Troll </a></li>
# <li><a class="trending-bar__link" data-qa="trending-bar-item" href="https://www.rottentomatoes.com/m/bullet_train_2022"> Bullet Train </a></li>
# <li><a class="trending-bar__link" data-qa="trending-bar-item" href="https://www.rottentomatoes.com/m/violent_night"> Violent Night </a></li>
# ...

# %%
#Audience Stars
test9 = BS(requests.get(f'https://www.rottentomatoes.com/m/The_Shawshank_Redemption', headers = headers).text)
test9.findAll('div')[1].find('star-rating').get('averagestars')
# Out:
# ----------------------------------------------------------------------
# AttributeError                       Traceback (most recent call last)
# Input In [53], in <cell line: 3>()
#       1 #Audience Stars
#       2 test9 = BS(requests.get(f'https://www.rottentomatoes.com/m/The_Shawshank_Redemption', headers = headers).text)
# ----> 3 test9.findAll('div')[1].find('star-rating').get('averagestars')
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %% [markdown]
# #### Trying to figure out issue movies with original language

# %%
#looking at parasite movie for original language
test10 = BS(requests.get(f'https://www.rottentomatoes.com/m/parasite', headers = headers).text)
test10.findAll('div', attrs = {'class':'meta-value'})[1].text.strip(' ').strip('\n')
# Out:
# 'English'

# %%
#looking at harakiri movie for original language
test10 = BS(requests.get(f'https://www.rottentomatoes.com/m/harakiri', headers = headers).text)
test10.findAll('div', attrs = {'class':'meta-value'})[1].text.strip(' ').strip('\n')
# Out:
# 'Japanese'

# %%
#looking at grave_of_the_fireflies movie for original language
test10 = BS(requests.get(f'https://www.rottentomatoes.com/m/grave_of_the_fireflies', headers = headers).text)
test10.findAll('div', attrs = {'class':'meta-value'})[1].text.strip(' ').strip('\n')
# Out:
# 'Japanese'
